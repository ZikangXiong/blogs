# %% [markdown]
# # DeepSynth: Automata Synthesis for Automatic Task Segmentation in Deep Reinforcement Learning
# [link](https://arxiv.org/pdf/1911.10244.pdf)
# [code](https://github.com/grockious/deepsynth)
#
# ## Main Idea
# This paper synthesized an automaton for the Montezuma's Revenge with collected trace with approach proposed [here](https://arxiv.org/pdf/2001.05230.pdf). The states in traces are images, thus they extract the objects from images and use the overlapping between objects to represent the state of DFA.
#
# ![image.png](attachment:9837d6d6-c52b-4a66-94c5-ce73a40b1f87.png)
# ![image.png](attachment:89c9156c-e181-4477-a5f3-cda415c8e69c.png)
#
# ![image.png](attachment:48eaaeb9-30e5-4d58-ac84-33123c85ee1e.png)

# %% [markdown]
# After synthesizing the DFA, they use the DFA to augment the Q value (some proof and rephrasing from RL perspective are needed here. Will the optimal reward with such policy be the best policy? This breaks the MC property.)
# Since the DFA can provide richer reward information, thus better training results are expected.
#
# Some other benchmarks are provided in their code.

# %% [markdown]
# ## Some thoughts
#
# There are some points worth exploring:
#
# 1. The DFA is not learning, it just uses the previous data collected in one run ([code](https://github.com/grockious/deepsynth/blob/348a74e4de2dfd7b4eb84cd1f5cbd0965dd64266/training.py#L549)). Thus a learnable structure may provide better benefits.
# 2. After getting the DFA, the paper mentioned that a verifier is used to check whether all the transitions satisfy the DFA. Why all transitions? Some transitions must be fail to explore the space. This part needs some rephrasing. I prefer reconstructing this idea as find some high reward traces which do not have any counter-example for this DFA.
# 3. The image segmentation is done by hand ([code](https://github.com/grockious/deepsynth/blob/348a74e4de2dfd7b4eb84cd1f5cbd0965dd64266/training.py#L687)), which is hard to generalize to different task. Some algorithm to auto generate such segmentation will be a great step. I will consider using autoencoder here.
# 4. Richer temporal expression. DFA to LTL?
# 5. Pre-knowledge to encode DFA.
# 6. LSTM/transformer to handle the temporal relation.
# 7. Instead of simply enhancing the Q value for reward shaping, considering attention.
# 8. A related paper [code](https://openreview.net/pdf?id=M_gk45ItxIp).
