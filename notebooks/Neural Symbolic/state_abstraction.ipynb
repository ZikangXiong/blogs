# %% [markdown]
# # State Abstraction
#
# [Uniform State Abstraction For Reinforcement Learning](#Uniform-State-Abstraction-For-Reinforcement-Learning)
# [Hierarchical Deep Reinforcement Learning: Integrating Temporal Abstraction and Intrinsic Motivation](#Hierarchical-Deep-Reinforcement-Learning:-Integrating-Temporal-Abstraction-and-Intrinsic-Motivation)

# %% [markdown]
# ## Uniform State Abstraction For Reinforcement Learning
# [link](https://arxiv.org/pdf/2004.02919.pdf)
#
# ### Summary
# This work extend the [MultiGrid Reinforcement Learning](https://www.researchgate.net/profile/Marek-Grzes/publication/225107729_Multigrid_Reinforcement_Learning_with_Reward_Shaping/links/53da52140cf2e38c63367a30/Multigrid-Reinforcement-Learning-with-Reward-Shaping.pdf) to deep RL. It built a high-level Abstract MDP (AMDP) which can be solved by dynamic programming, and used the built AMDP to shape the reward.
#
# ### Details
# - The state abstract is built with splitting the state space.
# - Need to build the AMDP before use it for reward shaping. The AMDP is built with exploration space without update neural network.
# - The reward of AMDP is estimated with collected transitions in exploration phase, or simply set as -1 and the agent will stop after reach the goal states.
# - Requires that one or more abstract states are selected as goal states.
# - The goal states in AMDP are selected with a policy trained with value iteration on the AMDP.
# - The evaluation works well on very simple low dimension cases.

# %% [markdown]
# ## Hierarchical Deep Reinforcement Learning: Integrating Temporal Abstraction and Intrinsic Motivation
# [link](https://arxiv.org/pdf/1604.06057.pdf)
#
# ![image.png](attachment:c2364bdc-dbe9-47d5-89eb-7aea30cc3206.png)
# The upper-level controller produces a goal for the low level critic. The experiments are evaluated on the Montezuma’s Revenge with spare reward.

# %% [markdown]
# ## DAQN
# [link](https://arxiv.org/pdf/1710.00459.pdf)
