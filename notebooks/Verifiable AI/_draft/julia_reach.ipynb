# %% [markdown]
# # Julia Reach
# [link](https://github.com/JuliaReach/ARCH2020_AFF_RE.git)

# %% [markdown]
# This tool won the best reward award for [ARCH20](https://cps-vo.org/group/ARCH) competition.

# %% [markdown]
# ## Install

# %%
# %%sh
# cd res/
# git clone https://github.com/JuliaReach/ARCH2020_NLN_RE.git

# %% [markdown]
# ## Run Non-Linear Benchmarks Results
#
# ```sh
# Running NLN benchmarks...
# ###
# Running production-destruction model benchmark
# ###
# volume final box, case I : 3.3e-20
# volume final box, case P : 5.3e-21
# volume final box, case IP : 1.0e-20
# (1/1) benchmarking "PRDE20"...
#   (1/3) benchmarking "I"...
#   done (took 6.674756081 seconds)
#   (2/3) benchmarking "IP"...
#   done (took 6.225679618 seconds)
#   (3/3) benchmarking "P"...
#   done (took 8.242834589 seconds)
# done (took 22.006159936 seconds)
# minimum time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "PRDE20" => 3-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "I" => TrialEstimate(1.432 s)
#           "IP" => TrialEstimate(2.690 s)
#           "P" => TrialEstimate(3.769 s)
# median time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "PRDE20" => 3-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "I" => TrialEstimate(1.453 s)
#           "IP" => TrialEstimate(2.774 s)
#           "P" => TrialEstimate(3.773 s)
# ###
# Running Van der Pol benchmark
# ###
# (1/1) benchmarking "CVDP20"...
#   (1/2) benchmarking "μ=2.0"...
#   done (took 33.082181001 seconds)
#   (2/2) benchmarking "μ=1.0"...
#   done (took 6.795283625 seconds)
# done (took 41.366483299 seconds)
# minimum time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "CVDP20" => 2-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "μ=2.0" => TrialEstimate(31.548 s)
#           "μ=1.0" => TrialEstimate(329.224 ms)
# median time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "CVDP20" => 2-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "μ=2.0" => TrialEstimate(31.548 s)
#           "μ=1.0" => TrialEstimate(349.367 ms)
# ###
# Running Laub-Loomis benchmark
# ###
# width of final box, case W=0.01 : 0.00422669680166976
# width of final box, case W=0.05: 0.017462225836897716
# width of final box, case W=0.1 : 0.03362699736716124
# (1/1) benchmarking "LALO20"...
#   (1/3) benchmarking "W=0.01"...
#   done (took 7.471889641 seconds)
#   (2/3) benchmarking "W=0.1"...
#   done (took 7.659261348 seconds)
#   (3/3) benchmarking "W=0.05"...
#   done (took 7.808654464 seconds)
# done (took 24.511406121 seconds)
# minimum time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "LALO20" => 3-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "W=0.01" => TrialEstimate(916.691 ms)
#           "W=0.1" => TrialEstimate(1.176 s)
#           "W=0.05" => TrialEstimate(1.172 s)
# median time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "LALO20" => 3-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "W=0.01" => TrialEstimate(990.617 ms)
#           "W=0.1" => TrialEstimate(1.195 s)
#           "W=0.05" => TrialEstimate(1.246 s)
# ###
# Running Quadrotor benchmark
# ###
# Validate property, case Δ=0.1 : true
# Validate property, case Δ=0.4 : true
# Validate property, case Δ=0.8 : false
# (1/1) benchmarking "QUAD20"...
#   (1/3) benchmarking "Δ=0.1"...
#   done (took 7.361778756 seconds)
#   (2/3) benchmarking "Δ=0.4"...
#   done (took 7.390447039 seconds)
#   (3/3) benchmarking "Δ=0.8"...
#   done (took 7.452785407 seconds)
# done (took 23.887013896 seconds)
# minimum time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "QUAD20" => 3-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "Δ=0.1" => TrialEstimate(1.838 s)
#           "Δ=0.4" => TrialEstimate(1.367 s)
#           "Δ=0.8" => TrialEstimate(1.377 s)
# median time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "QUAD20" => 3-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "Δ=0.1" => TrialEstimate(1.897 s)
#           "Δ=0.4" => TrialEstimate(1.411 s)
#           "Δ=0.8" => TrialEstimate(1.430 s)
# ###
# Running Lotka-Volterra tangential crossing benchmark
# ###
# tmin = 2.6607663522539795
# tmax = 2.843324138086564
# tmax - tmin = 0.18255778583258442
# Final area, case  : 0.002201292698526464
# Time spent in guard, case  : 0.18255778583258442
# (1/1) benchmarking "LOVO20"...
#   (1/1) benchmarking ""...
#   done (took 7.940265203 seconds)
# done (took 9.734489552 seconds)
# minimum time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "LOVO20" => 1-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "" => TrialEstimate(6.123 s)
# median time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "LOVO20" => 1-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "" => TrialEstimate(6.123 s)
# ###
# Spacecraft benchmark
# ###
# Line of sight property: true
# Velocity constraint property true
# Target avoidance property: true
# (1/1) benchmarking "SPRE20"...
#   (1/1) benchmarking ""...
#   done (took 17.549208451 seconds)
# done (took 19.535888852 seconds)
# minimum time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "SPRE20" => 1-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "" => TrialEstimate(15.483 s)
# median time for each benchmark:
# 1-element BenchmarkTools.BenchmarkGroup:
#   tags: []
#   "SPRE20" => 1-element BenchmarkTools.BenchmarkGroup:
#           tags: []
#           "" => TrialEstimate(15.483 s)
# Finished running benchmarks.
# ```
