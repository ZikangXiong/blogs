# %% [markdown]
# # Mining Requirements from Closed-Loop Control Models
# [link](http://alumni.cs.ucr.edu/~jinx/papers/HSCC2013.pdf)
#
# ![image.png](attachment:1df89b2e-86e3-403f-9508-52ee7b9cbcac.png)

# %% [markdown]
# Pioneer work on the mining requirement (specification) on CPS system.
# 1. Need predefined template specification.
# 2. Effective solver required, otherwise hard to scale up.
