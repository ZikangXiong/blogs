# %% [markdown]
# # THE NEURO-SYMBOLIC CONCEPT LEARNER: INTERPRETING SCENES, WORDS, AND SENTENCES FROM NATURAL SUPERVISION
# [link](http://nscl.csail.mit.edu/data/papers/2019ICLR-NSCL.pdf)

# %% [markdown]
# ![image.png](attachment:2c3fa91e-82d8-4e61-acb2-eee8d0c97bd6.png)
